# %%
import osmnx as ox
import geopandas as gpd
import networkx as nx
from shapely.geometry import Point
import numpy as np
import seaborn as sns
import pandas as pd
import requests
import xml.etree.ElementTree as ET
import h3
from shapely import wkt
from shapely.geometry import box, Polygon
import folium

# Load data
all_lts_df = pd.read_csv("/Users/leonardo/Desktop/Tesi/LTSBikePlan/data/Montereale_Valcellina_all_lts.csv")
all_lts_df['geometry'] = all_lts_df['geometry'].apply(wkt.loads)
gdf_nodes = pd.read_csv("/Users/leonardo/Desktop/Tesi/LTSBikePlan/data/Montereale_Valcellina_gdf_nodes.csv", index_col=0)
gdf_nodes['geometry'] = gdf_nodes['geometry'].apply(wkt.loads)

#Convert the DataFrame to a GeoDataFrame
all_lts = gpd.GeoDataFrame(all_lts_df, geometry='geometry')
all_lts.crs = "EPSG:32632"
all_lts_projected = all_lts.to_crs(epsg=4326)

nodes = gpd.GeoDataFrame(gdf_nodes, geometry='geometry')
nodes.crs = "EPSG:32632"
nodes_projected = nodes.to_crs(epsg=4326)

def classify_stress(row):
    if pd.notna(row['lts']):  # Checks if 'lts' value is not NaN
        if row['lts'] in [1, 2]:
            return 'low'
        elif row['lts'] in [3, 4]:
            return 'high'
    return None  # Returns None for NaN or unclassified values

# Apply the function to create 'type_stress' column
all_lts_projected['type_stress'] = all_lts_projected.apply(classify_stress, axis=1)
nodes_projected['type_stress'] = nodes_projected.apply(classify_stress, axis=1)

# Create a network
G = nx.Graph()
# Add nodes from nodes_projected
for idx, row in nodes_projected.iterrows():
    # Add node with attributes
    G.add_node(idx, **row.to_dict())

# Add edges from all_lts_projected
for _, row in all_lts_projected.iterrows():
    # Extract start and end node IDs
    u = row['u']
    v = row['v']
    # Add edge with attributes
    G.add_edge(u, v, **row.to_dict())

print(f"Number of nodes: {G.number_of_nodes()}")
print(f"Number of edges: {G.number_of_edges()}")

# Print node attributes
if G.number_of_nodes() > 0:
    first_node = next(iter(G.nodes))
    print("Node Attributes:", list(G.nodes[first_node].keys()))
else:
    print("No nodes in the graph.")

# Print edge attributes
if G.number_of_edges() > 0:
    first_edge = next(iter(G.edges))
    print("Edge Attributes:", list(G.edges[first_edge].keys()))
else:
    print("No edges in the graph.")
# Out:
# Number of nodes: 1233
# Number of edges: 1104
# Node Attributes: ['y', 'x', 'street_count', 'highway', 'ref', 'geometry', 'lts', 'message', 'type_stress']
# Edge Attributes: ['u', 'v', 'key', 'osmid', 'lanes', 'name', 'highway', 'maxspeed', 'geometry', 'length', 'rule', 'lts', 'group', 'slope', 'slope_class', 'lanes_assumed', 'maxspeed_assumed', 'message', 'short_message', 'type_stress']

# %%
# Function to retrieve population data from OpenStreetMap
def get_osm_population(city_name):
    # Construct the Overpass API query
    query = f"""
    [out:xml][timeout:25];
    area[name="{city_name}"]->.searchArea;
    (
      node["population"](area.searchArea);
      way["population"](area.searchArea);
      relation["population"](area.searchArea);
    );
    out body;
    """
    url = "https://overpass-api.de/api/interpreter"
    
    # Send the request
    response = requests.get(url, params={'data': query})
    
    # Parse the XML response
    root = ET.fromstring(response.content)
    
    # Extract population data
    for element in root.iter('tag'):
        if element.attrib['k'] == 'population':
            return element.attrib['v']
    
    return "Population data not found"

# Retrieve population data for the specific city
total_city_population = int(get_osm_population("Montereale Valcellina"))

# Function to create a hexagonal grid within the city boundaries
def create_hex_grid_within_city_bounds(city_boundary, resolution):
    # Generate hexagons within the city boundary
    hexagons = h3.polyfill(city_boundary.__geo_interface__, resolution, geo_json_conformant=True)

    filtered_hexagons = []
    for h in hexagons:
        hex_polygon = Polygon(h3.h3_to_geo_boundary(h, geo_json=True))
        if hex_polygon.intersects(city_boundary):
            filtered_hexagons.append(hex_polygon)

    hex_grid = gpd.GeoDataFrame([{'geometry': hexagon} for hexagon in filtered_hexagons])
    hex_grid.crs = 'EPSG:4326'

    return hex_grid

# Create the hex grid within the city boundaries
city_boundary = all_lts_projected.geometry.unary_union.buffer(0.005)
hex_grid_within_city = create_hex_grid_within_city_bounds(city_boundary, 9)
hex_grid_projected = hex_grid_within_city.to_crs('EPSG: 32632')

# Calculate area for each hexagon to distribute population
hex_grid_projected['area'] = hex_grid_projected['geometry'].area

# Distribute the city's population across the hexagons
hex_grid_projected['estimated_population'] = (hex_grid_projected['area'] / hex_grid_projected['area'].sum()) * total_city_population

# Project the hex grid back to the original CRS for consistency with other data
hex_grid_projected = hex_grid_projected.to_crs('EPSG:4326')

# Choose an appropriate projected CRS for centroid calculation
projected_crs = 'EPSG:32632'  # Replace with a CRS that's appropriate for your area

# Project the all_lts data to the new CRS for centroid calculation
all_lts_projected_crs = all_lts_projected.to_crs(projected_crs)

# Calculate centroids
centroids = all_lts_projected_crs.geometry.centroid

# Reproject centroids back to the original CRS
centroids = centroids.to_crs(epsg=4326)

# Get the center latitude and longitude for the map
center_lat, center_lon = centroids.iloc[0].y, centroids.iloc[0].x

# Convert the hexagonal grid to GeoJSON for visualization
hex_grid_geojson = hex_grid_projected.to_json()

# Function to retrieve building data 
def get_building_data(city_name):
    # Retrieve buildings from OSM within the city boundary
    buildings = ox.features_from_place(city_name, tags={'building': True})
    return buildings

# Retrieve building data for Montereale Valcellina
buildings = get_building_data("Montereale Valcellina, Italy")

# Ensure CRS match between buildings and hex grid
buildings = buildings.to_crs(hex_grid_projected.crs)

# Ensure hex_grid_projected has an explicit index column
hex_grid_projected.reset_index(inplace=True)
hex_grid_projected.rename(columns={'index': 'hex_index'}, inplace=True)

# Spatial join to count buildings in each hexagon
hex_grid_with_buildings = gpd.sjoin(hex_grid_projected, buildings, how='left', predicate='intersects')

# Count buildings based on the hexagon index
building_counts = hex_grid_with_buildings.groupby('hex_index').size()

# Assign building counts to the hex grid
hex_grid_projected['building_count'] = hex_grid_projected['hex_index'].map(building_counts).fillna(0)

# Adjust population estimation based on building count
# Here: simple average of area-based and building-based estimates
hex_grid_projected['adjusted_population'] = hex_grid_projected.apply(
    lambda row: (row['estimated_population'] + row['building_count']) / 2, axis=1)
assert 'adjusted_population' in hex_grid_projected.columns, "Adjusted population column not found"

# Convert the hexagonal grid to GeoJSON for visualization
hex_grid_geojson = hex_grid_projected.to_crs(epsg=4326).to_json()

m = folium.Map(location=[center_lat, center_lon], zoom_start=13)

def color_function(feature):
    population = feature['properties']['adjusted_population']
    
    high_population_threshold = total_city_population * 0.02  # 2% of total population
    medium_population_threshold = total_city_population * 0.01  # 1% of total population

    if population > high_population_threshold:
        return '#ff0000'  # Red 
    elif population > medium_population_threshold:
        return '#ffff00'  # Yellow 
    else:
        return '#00ff00'  # Green 

folium.GeoJson(
    hex_grid_geojson,
    name='Hexagonal Grid',
    style_function=lambda feature: {
        'fillColor': color_function(feature),
        'color': 'black',
        'weight': 1,
        'fillOpacity': 0.5,
    }
).add_to(m)

# Add layer control and display the map
folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_74d0533a119d9035d5ab0bdded2cd2f6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_74d0533a119d9035d5ab0bdded2cd2f6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_74d0533a119d9035d5ab0bdded2cd2f6 = L.map(
#                 &quot;map_74d0533a119d9035d5ab0bdded2cd2f6&quot;,
#                 {
#                     center: [46.13631237879835, 12.64138561657496],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_33386b36e4eedec232c0e43c598cc211 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_74d0533a119d9035d5ab0bdded2cd2f6);
#
#
#         function geo_json_e278f52d0df1de7f29b0987651cf2c5f_styler(feature) {
#             switch(feature.id) {
#                 case &quot;57&quot;: case &quot;59&quot;: case &quot;84&quot;: case &quot;143&quot;: case &quot;170&quot;: case &quot;190&quot;: case &quot;199&quot;: case &quot;311&quot;: case &quot;312&quot;: case &quot;321&quot;: case &quot;337&quot;: case &quot;356&quot;: case &quot;397&quot;: case &quot;434&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffff00&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#00ff00&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_e278f52d0df1de7f29b0987651cf2c5f_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_e278f52d0df1de7f29b0987651cf2c5f = L.geoJson(null, {
#                 onEachFeature: geo_json_e278f52d0df1de7f29b0987651cf2c5f_onEachFeature,
#
#                 style: geo_json_e278f52d0df1de7f29b0987651cf2c5f_styler,
#         });
#
#         function geo_json_e278f52d0df1de7f29b0987651cf2c5f_add (data) {
#             geo_json_e278f52d0df1de7f29b0987651cf2c5f
#                 .addData(data)
#                 .addTo(map_74d0533a119d9035d5ab0bdded2cd2f6);
#         }
#             geo_json_e278f52d0df1de7f29b0987651cf2c5f_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[12.637124084362505, 46.133055490815494], [12.637255221316275, 46.13127713861746], [12.639627820351441, 46.13054164291665], [12.641869367848294, 46.13158448918272], [12.641738331576942, 46.13336285730156], [12.63936564712447, 46.13409836323477], [12.637124084362505, 46.133055490815494]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;adjusted_population&quot;: 4.505812868245402, &quot;area&quot;: 106368.6900414735, &quot;building_count&quot;: 1, &quot;estimated_population&quot;: 8.011625736490805, &quot;hex_index&quot;: 0}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[12.674823398964572, 46.12483793960674], [12.67495369554378, 46.123059244008125], [12.677326062772412, 46.122322805227405], [12.679568218704265, 46.123365051761674], [12.679438022838163, 46.12514376322498], [12.677065570325247, 46.12588021229061], [12.674823398964572, 46.12483793960674]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;adjusted_population&quot;: 4.507439515574459, &quot;area&quot;: 106411.88335859594, &quot;building_count&quot;: 1, &quot;estimated_population&quot;: 8.014879031148919, &quot;hex_index&quot;: 1}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[12.66152440496865, 46.14808091585791], [12.661655031577538, 46.14630274660059], [12.664028090618137, 46.145566904357004], [12.666270608423051, 46.146609221098515], [12.66614008256823, 46.148387406230576], [12.663766938152557, 46.14912325874765], [12.66152440496865, 46.14808091585791]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;2&quot;, &quot;properties&quot;: {&quot;adjusted_population&quot;: 6.005527830498048, &quot;area&quot;: 106361.12126759521, &quot;building_count&quot;: 4, &quot;estimated_population&quot;: 8.011055660996096, &quot;hex_index&quot;: 2}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[12.620915180749233, 46.164135619630926], [12.621046724800495, 46.16235796435375], [12.623420249222539, 46.16162323185878], [12.625662315125425, 46.16266614442278], [12.625530871813465, 46.16444381563158], [12.623157261857445, 46.165178558346035], [12.620915180749233, 46.164135619630926]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;3&quot;, &quot;properties&quot;: {&quot;adjusted_population&quot;: 4.503301510554599, &quot;area&quot;: 106

# %%
# Spatial join between hexagons and edges
edges_gdf = gpd.GeoDataFrame(all_lts_projected[['geometry', 'u', 'v', 'type_stress']], geometry='geometry')
hex_edges = gpd.sjoin(hex_grid_projected, edges_gdf, how='left', predicate='intersects')

# Group edges by hexagon using a list for column names
hexagon_edges = hex_edges.groupby('hex_index')[['u', 'v']].apply(lambda x: list(zip(x['u'], x['v'])))
# Remove hexagons with only NaN values in their edge list
filtered_hexagon_edges = {hex_id: edges for hex_id, edges in hexagon_edges.items() if not all(np.isnan(edge).any() for edge in edges)}

print(filtered_hexagon_edges)
# Out:
# {0: [(3506974525.0, 4187438666.0), (4187438666.0, 3506974525.0), (3506974548.0, 4187438666.0), (4187438666.0, 3506974548.0), (737610454.0, 481334646.0), (3506974548.0, 5018109329.0), (5018109329.0, 3506974548.0), (3506974548.0, 3506974552.0), (3506974552.0, 3506974548.0), (481334646.0, 3506974552.0), (3506974552.0, 481334646.0), (481334646.0, 481334639.0), (481334639.0, 481334646.0), (481334646.0, 737610454.0)], 1: [(3481946812.0, 1947733632.0), (1947733632.0, 3481946812.0), (1947733632.0, 564874543.0), (564874543.0, 1947733632.0), (1947733632.0, 3783691229.0), (3783691229.0, 1947733632.0), (1947733632.0, 1875944520.0), (1875944520.0, 1947733632.0)], 2: [(3452104942.0, 2143808112.0), (2143808112.0, 3452104942.0), (2143808184.0, 2143808112.0), (2143808112.0, 2143808184.0), (912306922.0, 2143808184.0), (2143808184.0, 912306922.0), (318694413.0, 912296263.0), (912296263.0, 318694413.0), (3481947868.0, 912311919.0), (912311919.0, 3481947868.0)], 6: [(1945789497.0, 3723637999.0), (3723637999.0, 1945789497.0), (1892343181.0, 1945789497.0), (1945789497.0, 1892343181.0)], 7: [(1812847640.0, 1812847619.0), (4703791334.0, 1812847619.0), (1812847619.0, 4703791334.0), (4703791334.0, 4703791323.0), (4703791323.0, 4703791334.0), (4703791322.0, 4703791334.0), (4703791334.0, 4703791322.0), (1812847619.0, 1812847640.0)], 8: [(4922167523.0, 4922167503.0), (4922167503.0, 4922167523.0), (4922167523.0, 1875944520.0), (1875944520.0, 4922167523.0)], 9: [(912288978.0, 912311986.0), (912309569.0, 3481947614.0), (912311986.0, 912303669.0), (912303669.0, 912298311.0), (912303669.0, 912308859.0), (3481947614.0, 912311986.0), (3868226364.0, 2078574772.0), (2078574772.0, 3868226364.0), (275047807.0, 912293688.0), (912293688.0, 275047807.0), (3868226364.0, 3868226364.0), (912309569.0, 3481947816.0), (3481947816.0, 912309569.0)], 10: [(4230598295.0, 3506974464.0), (3506974464.0, 4230598295.0), (3741330043.0, 3506974464.0), (3506974464.0, 3741330043.0), (3506974430.0, 3506974464.0), (3506974464.0, 3506974430.0), (3741330043.0, 4230598296.0), (4230598296.0, 3741330043.0), (1946089831.0, 4230598296.0), (4230598296.0, 1946089831.0)], 11: [(1879110733.0, 3812605343.0), (3812605343.0, 1879110733.0), (540415177.0, 1879110733.0), (1879110733.0, 540415177.0), (540415177.0, 3824639465.0), (3824639465.0, 540415177.0), (1879110737.0, 1879110733.0), (1879110733.0, 1879110737.0), (3824639465.0, 3824635253.0), (3824635253.0, 3824639465.0), (1812813611.0, 3824639465.0), (3824639465.0, 1812813611.0)], 13: [(1769453990.0, 1894585953.0), (1894585953.0, 1769453990.0)], 14: [(481334646.0, 481334639.0), (481334639.0, 481334646.0)], 15: [(275047807.0, 912293688.0), (912293688.0, 275047807.0), (3481947860.0, 3481947803.0), (3481947803.0, 3481947860.0), (3481947816.0, 3481947860.0), (3481947860.0, 3481947816.0), (3452104947.0, 3452104942.0), (3452104942.0, 3452104947.0), (3452104947.0, 3481947860.0), (3481947867.0, 3481947860.0), (3481947860.0, 3481947867.0), (3481947860.0, 3452104947.0), (3452104942.0, 2143808112.0), (2143808112.0, 3452104942.0), (3452104947.0, 2143808184.0), (2143808184.0, 3452104947.0)], 16: [(1879110733.0, 3812605343.0), (3812605343.0, 1879110733.0)], 17: [(3506974525.0, 3506974487.0), (3506974487.0, 3506974525.0), (3783691200.0, 3783691251.0), (3783691251.0, 3783691200.0), (3506974525.0, 4187438666.0), (4187438666.0, 3506974525.0), (3824639635.0, 3824639642.0), (3824639642.0, 3824639635.0), (3506974548.0, 5018109329.0), (5018109329.0, 3506974548.0)], 18: [(3506974512.0, 3783691195.0), (3783691195.0, 3506974512.0), (3506974512.0, 3783691600.0), (3783691600.0, 3506974512.0), (3723638012.0, 3680118469.0), (3680118469.0, 3723638012.0)], 19: [(1875944496.0, 4922167481.0), (665371590.0, 4922167481.0), (4922167481.0, 665371590.0), (4922167481.0, 1875944496.0)], 21: [(3723637983.0, 4230598077.0), (4230598077.0, 3723637983.0)], 22: [(3452111732.0, 912290685.0), (912290685.0, 3452111732.0), (3452111732.0, 3452111693.0), (3452111693.0, 3452111732.0), (3452111693.0, 912302 ...

# %%
# Assuming you have a function to find the centroid of a hexagon
def find_hexagon_centroid(hexagon_geometry):
    return hexagon_geometry.centroid

# Find the representative node for each hexagon
representative_nodes = {}
for hex_id, edges in filtered_hexagon_edges.items():
    hexagon_geometry = hex_grid_projected.loc[hex_grid_projected['hex_index'] == hex_id, 'geometry'].iloc[0]
    centroid = find_hexagon_centroid(hexagon_geometry)
    
    # Find the closest node to the centroid among the nodes of the hexagon's edges
    closest_node = None
    min_distance = float('inf')
    for u, v in edges:
        for node in [u, v]:
            if node in G.nodes:  # Check if the node is in the graph
                node_geom = Point(G.nodes[node]['x'], G.nodes[node]['y'])  # assuming nodes have 'x' and 'y' attributes
                distance = node_geom.distance(centroid)
                if distance < min_distance:
                    closest_node = node
                    min_distance = distance

    representative_nodes[hex_id] = closest_node

#print(representative_nodes)

shortest_paths = {}
for hex_id, start_node in representative_nodes.items():
    shortest_paths[hex_id] = {}
    for target_hex_id, target_node in representative_nodes.items():
        if hex_id != target_hex_id:
            if nx.has_path(G, start_node, target_node):  # Check if a path exists
                path_length = nx.dijkstra_path_length(G, source=start_node, target=target_node, weight='length')  # Assuming 'length' is the edge attribute for distance
                shortest_paths[hex_id][target_hex_id] = path_length
            else:
                shortest_paths[hex_id][target_hex_id] = None  # Indicate no path exists

# %%
# Create a subgraph with only low-stress edges
G_low_stress = nx.Graph()

# Add nodes to the subgraph
for node, data in G.nodes(data=True):
    G_low_stress.add_node(node, **data)

# Add only low-stress edges to the subgraph
for u, v, data in G.edges(data=True):
    if data.get('type_stress') == 'low':
        G_low_stress.add_edge(u, v, **data)


shortest_paths_low_stress = {}
for hex_id, start_node in representative_nodes.items():
    shortest_paths_low_stress[hex_id] = {}
    for target_hex_id, target_node in representative_nodes.items():
        if hex_id != target_hex_id:
            if nx.has_path(G_low_stress, start_node, target_node):  # Check if a path exists in the low-stress graph
                path_length = nx.dijkstra_path_length(G_low_stress, source=start_node, target=target_node, weight='length')  # Use the low-stress graph
                shortest_paths_low_stress[hex_id][target_hex_id] = path_length
            else:
                shortest_paths_low_stress[hex_id][target_hex_id] = None  # Indicate no path exists

#shortest_paths_low_stress

# %%
hexagon_connections = {}
detour_threshold = 1.5
for hex_id in shortest_paths:
    hexagon_connections[hex_id] = {}
    for target_hex_id in shortest_paths[hex_id]:
        baseline_path_length = shortest_paths[hex_id][target_hex_id]
        low_stress_path_length = shortest_paths_low_stress[hex_id][target_hex_id]

        # Check if the low-stress path exists and is within the threshold
        if low_stress_path_length is not None and (baseline_path_length is None or low_stress_path_length <= baseline_path_length * detour_threshold):
            hexagon_connections[hex_id][target_hex_id] = True
        else:
            hexagon_connections[hex_id][target_hex_id] = False

# hexagon_connections now contains information about which hexagons are connected via low-stress paths
hexagon_connections
# Out:
# {0: {1: False,
#   2: False,
#   6: False,
#   7: False,
#   8: False,
#   9: False,
#   10: True,
#   11: False,
#   13: False,
#   14: True,
#   15: False,
#   16: False,
#   17: True,
#   18: False,
#   19: False,
#   21: False,
#   22: False,
#   23: False,
#   25: False,
#   27: False,
#   28: False,
#   31: False,
#   32: False,
#   33: False,
#   35: False,
#   36: False,
#   37: False,
#   38: False,
#   39: False,
#   43: False,
#   46: True,
#   47: False,
#   48: False,
#   49: False,
#   51: False,
#   52: False,
#   53: False,
#   56: False,
#   57: False,
#   58: False,
#   59: True,
#   60: False,
#   61: False,
#   62: False,
#   64: False,
#   65: False,
#   66: False,
#   68: False,
#   69: False,
#   70: False,
#   72: False,
#   73: False,
#   75: False,
#   77: False,
#   78: False,
#   80: False,
#   81: False,
#   82: True,
#   83: False,
#   84: False,
#   86: True,
#   87: False,
#   89: True,
#   90: False,
#   91: False,
#   92: False,
#   93: False,
#   95: False,
#   97: False,
#   98: False,
#   99: False,
#   100: False,
#   101: False,
#   105: False,
#   106: False,
#   109: False,
#   110: False,
#   112: True,
#   113: False,
#   116: False,
#   118: False,
#   119: False,
#   120: False,
#   121: False,
#   122: False,
#   123: False,
#   124: False,
#   126: False,
#   128: False,
#   129: False,
#   131: True,
#   133: False,
#   134: False,
#   135: False,
#   137: False,
#   138: False,
#   139: True,
#   140: False,
#   141: False,
#   142: False,
#   143: False,
#   144: False,
#   145: True,
#   146: False,
#   148: False,
#   151: False,
#   153: False,
#   154: False,
#   156: False,
#   157: False,
#   158: False,
#   159: False,
#   160: False,
#   163: False,
#   164: False,
#   167: False,
#   169: False,
#   170: False,
#   171: False,
#   172: False,
#   173: False,
#   174: False,
#   177: False,
#   178: False,
#   181: False,
#   182: False,
#   186: True,
#   187: False,
#   188: False,
#   190: False,
#   192: False,
#   193: False,
#   194: False,
#   195: False,
#   196: False,
#   197: False,
#   198: False,
#   199: False,
#   202: False,
#   204: False,
#   205: True,
#   206: False,
#   207: False,
#   208: False,
#   209: False,
#   210: False,
#   212: False,
#   213: False,
#   214: False,
#   219: False,
#   220: False,
#   221: False,
#   222: False,
#   223: False,
#   224: False,
#   228: False,
#   229: False,
#   230: False,
#   231: False,
#   232: False,
#   233: False,
#   235: False,
#   237: False,
#   238: False,
#   239: False,
#   241: False,
#   242: False,
#   243: False,
#   244: False,
#   245: False,
#   247: True,
#   248: False,
#   249: False,
#   253: True,
#   254: False,
#   255: False,
#   256: True,
#   257: False,
#   258: False,
#   260: False,
#   262: False,
#   263: False,
#   264: False,
#   265: False,
#   266: False,
#   267: False,
#   268: False,
#   272: False,
#   273: False,
#   275: False,
#   276: False,
#   277: False,
#   279: False,
#   280: False,
#   283: False,
#   285: False,
#   287: False,
#   288: True,
#   289: False,
#   290: False,
#   291: False,
#   292: False,
#   293: False,
#   294: True,
#   295: False,
#   298: False,
#   300: False,
#   301: True,
#   302: False,
#   303: False,
#   304: False,
#   305: False,
#   306: False,
#   307: False,
#   308: False,
#   310: False,
#   311: False,
#   312: False,
#   313: False,
#   316: False,
#   317: False,
#   320: False,
#   321: False,
#   322: False,
#   323: False,
#   324: False,
#   326: False,
#   327: False,
#   328: False,
#   330: False,
#   332: False,
#   333: False,
#   334: False,
#   335: True,
#   336: False,
#   337: False,
#   338: False,
#   339: False,
#   341: False,
#   343: True,
#   347: False,
#   349: False,
#   350: False,
#   351: False,
#   352: False,
#   353: False,
#   355: False,
#   356: False,
#   357: False,
#   358: False,
#   359: False,
#   360: False,
#   361: True,
#   362: False,
#   363: False,
#   364: False,
#   366: True,
#   367: False,
#   369: False,
#   370: False,
#   371: True,
#   372: False,
#   373: False,
#   374: False,
#   375: True,
#   377: False,
#   379: False,
#   380: False,
#   381: False,
#   383: False,
#   384: False,
#   385: False,
#   386: False,
#   387: True,
#   388: False,
#   390: True,
#   391: False,
#   392: False,
#   393: False,
#   394: False,
#   396: False,
#   397: False,
#   399: False,
#   401: False,
#   402: False,
#   403: False,
#   405: False,
#   406: False,
#   407: False,
#   408: False,
#   409: False,
#   411: False,
#   412: True,
#   413: False,
#   415: False,
#   416: False,
#   418: False,
#   419: False,
#   420: False,
#   421: False,
#   422: False,
#   424: False,
#   425: False,
#   426: False,
#   429: False,
#   430: False,
#   431: False,
#   432: False,
#   433: False,
#   434: False,
#   435: False,
#   436: False,
#   437: True,
#   438: False,
#   440: False,
#   441: False,
#   442: False,
#   443: False,
#   444: False,
#   446: False,
#   447: False,
#   448: False,
#   450: True,
#   452: False,
#   453: False,
#   455: False,
#   456: False,
#   457: False,
#   458: False,
#   459: False,
#   460: False,
#   461: False,
#   462: False,
#   463: False,
#   465: False,
#   466: False,
#   468: False,
#   469: False,
#   470: False,
#   471: True,
#   476: False,
#   478: False,
#   480: False,
#   481: False,
#   482: False,
#   485: True,
#   486: False,
#   487: False,
#   488: False,
#   489: False,
#   490: False,
#   491: False,
#   492: False,
#   495: False,
#   496: False,
#   497: False,
#   498: False,
#   499: True,
#   500: True,
#   501: False,
#   502: False,
#   505: False,
#   506: False,
#   507: False,
#   508: False,
#   509: False,
#   510: False,
#   511: False,
#   512: True,
#   514: False,
#   515: False,
#   516: False,
#   517: False,
#   518: False,
#   519: False,
#   524: False,
#   526: False,
#   529: False,
#   530: False,
#   531: False,
#   532: False,
#   533: False,
#   535: False,
#   537: False,
#   538: False,
#   539: False,
#   540: True,
#   541: False,
#   543: False,
#   544: False,
#   545: False,
#   547: False,
#   548: False,
#   549: False,
#   550: False,
#   551: False,
#   553: False,
#   554: False,
#   555: False,
#   556: False,
#   559: False,
#   560: False,
#   561: False,
#   564: False,
#   566: False,
#   569: False,
#   571: False,
#   573: False,
#   574: False,
#   575: False,
#   576: False,
#   577: False,
#   579: True,
#   580: False},
#  1: {0: False,
#   2: False,
#   6: False,
#   7: True,
#   8: True,
#   9: False,
#   10: False,
#   11: False,
#   13: False,
#   14: False,
#   15: False,
#   16: False,
#   17: False,
#   18: False,
#   19: False,
#   21: False,
#   22: False,
#   23: False,
#   25: False,
#   27: False,
#   28: False,
#   31: True,
#   32: False,
#   33: False,
#   35: False,
#   36: False,
#   37: False,
#   38: False,
#   39: False,
#   43: True,
#   46: False,
#   47: False,
#   48: True,
#   49: True,
#   51: False,
#   52: False,
#   53: False,
#   56: False,
#   57: False,
#   58: False,
#   59: False,
#   60: False,
#   61: False,
#   62: False,
#   64: False,
#   65: True,
#   66: False,
#   68: False,
#   69: True,
#   70: False,
#   72: False,
#   73: False,
#   75: False,
#   77: True,
#   78: False,
#   80: False,
#   81: True,
#   82: False,
#   83: False,
#   84: False,
#   86: False,
#   87: False,
#   89: False,
#   90: False,
#   91: False,
#   92: False,
#   93: False,
#   95: True,
#   97: False,
#   98: False,
#   99: False,
#   100: False,
#   101: False,
#   105: False,
#   106: False,
#   109: False,
#   110: False,
#   112: False,
#   113: False,
#   116: False,
#   118: False,
#   119: True,
#   120: False,
#   121: False,
#   122: True,
#   123: False,
#   124: False,
#   126: False,
#   128: True,
#   129: False,
#   131: False,
#   133: False,
#   134: False,
#   135: True,
#   137: False,
#   138: True,
#   139: False,
#   140: False,
#   141: False,
#   142: False,
#   143: False,
#   144: False,
#   145: False,
#   146: False,
#   148: False,
#   151: False,
#   153: False,
#   154: False,
#   156: False,
#   157: False,
#   158: False,
#   159: True,
#   160: False,
#   163: False,
#   164: False,
#   167: True,
#   169: False,
#   170: False,
#   171: False,
#   172: False,
#   173: False,
#   174: False,
#   177: True,
#   178: False,
#   181: True,
#   182: False,
#   186: False,
#   187: False,
#   188: False,
#   190: False,
#   192: False,
#   193: True,
#   194: False,
#   195: False,
#   196: False,
#   197: False,
#   198: False,
#   199: False,
#   202: False,
#   204: False,
#   205: False,
#   206: False,
#   207: False,
#   208: False,
#   209: False,
#   210: False,
#   212: False,
#   213: False,
#   214: False,
#   219: False,
#   220: False,
#   221: False,
#   222: True,
#   223: False,
#   224: True,
#   228: False,
#   229: False,
#   230: False,
#   231: False,
#   232: False,
#   233: False,
#   235: False,
#   237: False,
#   238: False,
#   239: False,
#   241: False,
#   242: False,
#   243: False,
#   244: False,
#   245: False,
#   247: False,
#   248: False,
#   249: True,
#   253: False,
#   254: False,
#   255: False,
#   256: False,
#   257: True,
#   258: False,
#   260: False,
#   262: False,
#   263: False,
#   264: True,
#   265: False,
#   266: False,
#   267: True,
#   268: False,
#   272: True,
#   273: False,
#   275: False,
#   276: False,
#   277: False,
#   279: True,
#   280: False,
#   283: False,
#   285: False,
#   287: False,
#   288: False,
#   289: True,
#   290: False,
#   291: False,
#   292: False,
#   293: False,
#   294: False,
#   295: False,
#   298: False,
#   300: False,
#   301: False,
#   302: False,
#   303: False,
#   304: False,
#   305: False,
#   306: False,
#   307: False,
#   308: False,
#   310: False,
#   311: False,
#   312: False,
#   313: False,
#   316: False,
#   317: False,
#   320: False,
#   321: False,
#   322: True,
#   323: False,
#   324: True,
#   326: True,
#   327: False,
#   328: True,
#   330: False,
#   332: False,
#   333: True,
#   334: True,
#   335: False,
#   336: False,
#   337: False,
#   338: False,
#   339: False,
#   341: False,
#   343: False,
#   347: False,
#   349: False,
#   350: False,
#   351: False,
#   352: True,
#   353: False,
#   355: False,
#   356: False,
#   357: False,
#   358: False,
#   359: False,
#   360: False,
#   361: False,
#   362: False,
#   363: True,
#   364: True,
#   366: False,
#   367: False,
#   369: True,
#   370: False,
#   371: False,
#   372: False,
#   373: False,
#   374: False,
#   375: False,
#   377: False,
#   379: True,
#   380: False,
#   381: True,
#   383: False,
#   384: False,
#   385: False,
#   386: False,
#   387: False,
#   388: False,
#   390: False,
#   391: True,
#   392: True,
#   393: False,
#   394: True,
#   396: False,
#   397: False,
#   399: True,
#   401: False,
#   402: False,
#   403: False,
#   405: False,
#   406: False,
#   407: False,
#   408: False,
#   409: True,
#   411: False,
#   412: False,
#   413: False,
#   415: False,
#   416: True,
#   418: False,
#   419: False,
#   420: True,
#   421: True,
#   422: True,
#   424: False,
#   425: False,
#   426: False,
#   429: False,
#   430: False,
#   431: False,
#   432: True,
#   433: False,
#   434: False,
#   435: False,
#   436: False,
#   437: False,
#   438: True,
#   440: False,
#   441: False,
#   442: False,
#   443: False,
#   444: False,
#   446: False,
#   447: False,
#   448: True,
#   450: False,
#   452: False,
#   453: False,
#   455: True,
#   456: False,
#   457: False,
#   458: False,
#   459: False,
#   460: False,
#   461: False,
#   462: True,
#   463: False,
#   465: False,
#   466: False,
#   468: False,
#   469: False,
#   470: False,
#   471: False,
#   476: True,
#   478: False,
#   480: False,
#   481: False,
#   482: True,
#   485: False,
#   486: False,
#   487: False,
#   488: False,
#   489: False,
#   490: False,
#   491: False,
#   492: False,
#   495: False,
#   496: False,
#   497: False,
#   498: False,
#   499: False,
#   500: False,
#   501: False,
#   502: False,
#   505: True,
#   506: True,
#   507: False,
#   508: False,
#   509: True,
#   510: True,
#   511: False,
#   512: False,
#   514: False,
#   515: False,
#   516: False,
#   517: False,
#   518: False,
#   519: False,
#   524: False,
#   526: False,
#   529: False,
#   530: False,
#   531: False,
#   532: True,
#   533: False,
#   535: False,
#   537: False,
#   538: False,
#   539: True,
#   540: False,
#   541: False,
#   543: True,
#   544: False,
#   545: False,
#   547: False,
#   548: False,
#   549: False,
#   550: False,
#   551: False,
#   553: False,
#   554: False,
#   555: False,
#   556: False,
#   559: False,
#   560: False,
#   561: True,
#   564: False,
#   566: False,
#   569: False,
#   571: False,
#   573: True,
#   574: False,
#   575: False,
#   576: False,
#   577: False,
#   579: False,
#   580: False},
#  2: {0: False,
#   1: False,
#   6: False,
#   7: False,
#   8: False,
#   9: False,
#   10: False,
#   11: False,
#   13: False,
#   14: False,
#   15: True,
#   16: False,
#   17: False,
#   18: False,
#   19: False,
#   21: False,
#   22: False,
#   23: False,
#   25: False,
#   27: False,
#   28: False,
#   31: False,
#   32: False,
#   33: False,
#   35: False,
#   36: False,
#   37: False,
#   38: False,
#   39: False,
#   43: False,
#   46: False,
#   47: False,
#   48: False,
#   49: False,
#   51: False,
#   52: False,
#   53: False,
#   56: False,
#   57: False,
#   58: False,
#   59: False,
#   60: False,
#   61: False,
#   62: False,
#   64: False,
#   65: False,
#   66: False,
#   68: False,
#   69: False,
#   70: False,
#   72: False,
#   73: False,
#   75: False,
#   77: False,
#   78: False,
#   80: False,
#   81: False,
#   82: False,
#   83: False,
#   84: False,
#   86: False,
#   87: False,
#   89: False,
#   90: False,
#   91: False,
#   92: False,
#   93: False,
#   95: False,
#   97: False,
#   98: False,
#   99: False,
#   100: False,
#   101: False,
#   105: False,
#   106: False,
#   109: False,
#   110: False,
#   112: False,
#   113: False,
#   116: False,
#   118: False,
#   119: False,
#   120: False,
#   121: False,
#   122: False,
#   123: False,
#   124: False,
#   126: False,
#   128: False,
#   129: False,
#   131: False,
#   133: False,
#   134: False,
#   135: False,
#   137: False,
#   138: False,
#   139: False,
#   140: False,
#   141: False,
#   142: False,
#   143: False,
#   144: False,
#   145: False,
#   146: False,
#   148: False,
#   151: False,
#   153: False,
#   154: False,
#   156: False,
#   157: False,
#   158: False,
#   159: False,
#   160: False,
#   163: False,
#   164: False,
#   167: False,
#   169: False,
#   170: False,
#   171: False,
#   172: False,
#   173: False,
#   174: False,
#   177: False,
#   178: False,
#   181: False,
#   182: False,
#   186: False,
#   187: False,
#   188: False,
#   190: False,
#   192: False,
#   193: False,
#   194: False,
#   195: False,
#   196: False,
#   197: False,
#   198: False,
#   199: False,
#   202: False,
#   204: False,
#   205: False,
#   206: False,
#   207: False,
#   208: False,
#   209: False,
#   210: False,
#   212: False,
#   213: False,
#   214: False,
#   219: False,
#   220: False,
#   221: False,
#   222: False,
#   223: False,
#   224: False,
#   228: False,
#   229: False,
#   230: False,
#   231: False,
#   232: False,
#   233: False,
#   235: False,
#   237: False,
#   238: False,
#   239: False,
#   241: False,
#   242: False,
#   243: False,
#   244: False,
#   245: False,
#   247: False,
#   248: False,
#   249: False,
#   253: False,
#   254: False,
#   255: False,
#   256: False,
#   257: False,
#   258: False,
#   260: False,
#   262: False,
#   263: False,
#   264: False,
#   265: False,
#   266: False,
#   267: False,
#   268: False,
#   272: False,
#   273: False,
#   275: False,
#   276: False,
#   277: False,
#   279: False,
#   280: False,
#   283: False,
#   285: False,
#   287: False,
#   288: False,
#   289: False,
#   290: False,
#   291: False,
#   292: False,
#   293: False,
#   294: False,
#   295: False,
#   298: False,
#   300: False,
#   301: False,
#   302: False,
#   303: False,
#   304: False,
#   305: False,
#   306: False,
#   307: False,
#   308: False,
#   310: False,
#   311: False,
#   312: False,
#   313: False,
#   316: False,
#   317: False,
#   320: False,
#   321: False,
#   322: False,
#   323: False,
#   324: False,
#   326: False,
#   327: False,
#   328: False,
#   330: False,
#   332: False,
#   333: False,
#   334: False,
#   335: False,
#   336: False,
#   337: False,
#   338: False,
#   339: False,
#   341: False,
#   343: False,
#   347: False,
#   349: False,
#   350: False,
#   351: False,
#   352: False,
#   353: False,
#   355: False,
#   356: False,
#   357: False,
#   358: False,
#   359: False,
#   360: False,
#   361: False,
#   362: False,
#   363: False,
#   364: False,
#   366: False,
#   367: False,
#   369: False,
#   370: False,
#   371: False,
#   372: False,
#   373: False,
#   374: False,
#   375: False,
#   377: False,
#   379: False,
#   380: False,
#   381: False,
#   383: False,
#   384: False,
#   385: False,
#   386: False,
#   387: False,
#   388: False,
#   390: False,
#   391: False,
#   392: False,
#   393: False,
#   394: False,
#   396: False,
#   397: False,
#   399: False,
#   401: False,
#   402: False,
#   403: False,
#   405: False,
#   406: False,
#   407: False,
#   408: False,
#   409: False,
#   411: False,
#   412: False,
#   413: False,
#   415: False,
#   416: False,
#   418: False,
#   419: False,
#   420: False,
#   421: False,
#   422: False,
#   424: False,
#   425: False,
#   426: False,
#   429: False,
#   430: False,
#   431: False,
#   432: False,
#   433: False,
#   434: False,
#   435: False,
#   436: False,
#   437: False,
#   438: False,
#   440: False,
#   441: False,
#   442: False,
#   443: False,
#   444: False,
#   446: False,
#   447: False,
#   448: False,
#   450: False,
#   452: False,
#   453: False,
#   455: False,
#   456: False,
#   457: False,
#   458: False,
#   459: False,
#   460: False,
#   461: False,
#   462: False,
#   463: False,
#   465: False,
#   466: False,
#   468: False,
#   469: False,
#   470: False,
#   471: False,
#   476: False,
#   478: False,
#   480: False,
#   481: False,
#   482: False,
#   485: False,
#   486: False,
#   487: False,
#   488: False,
#   489: False,
#   490: False,
#   491: False,
#   492: False,
#   495: False,
#   496: False,
#   497: False,
#   498: False,
#   499: False,
#   500: False,
#   501: False,
#   502: False,
#   505: False,
#   506: False,
#   507: False,
#   508: False,
#   509: False,
#   510: False,
#   511: False,
#   512: False,
#   514: False,
#   515: False,
#   516: False,
#   517: False,
#   518: False,
#   519: False,
#   524: False,
#   526: False,
#   529: False,
#   530: False,
#   531: False,
#   532: False,
#   533: False,
#   535: False,
#   537: False,
#   538: False,
#   539: False,
#   540: False,
#   541: False,
#   543: False,
#   544: False,
#   545: False,
#   547: False,
#   548: False,
#   549: False,
#   550: False,
#   551: False,
#   553: False,
#   554: False,
#   555: False,
#   556: False,
#   559: False,
#   560: False,
#   561: False,
#   564: False,
#   566: False,
#   569: False,
#   571: False,
#   573: False,
#   574: False,
#   575: False,
#   576: False,
#   577: False,
#   579: False,
#   580: False},
#  6: {0: False,
#   1: False,
#   2: False,
#   7: False,
#   8: False,
#   9: False,
#   10: False,
#   11: False,
#   13: False,
#   14: False,
#   15: False,
#   16: False,
#   17: False,
#   18: False,
#   19: False,
#   21: False,
#   22: False,
#   23: False,
#   25: False,
#   27: False,
#   28: False,
#   31: False,
#   32: False,
#   33: False,
#   35: False,
#   36: False,
#   37: False,
#   38: False,
#   39: False,
#   43: False,
#   46: False,
#   47: False,
#   48: False,
#   49: False,
#   51: False,
#   52: False,
#   53: False,
#   56: False,
#   57: False,
#   58: False,
#   59: False,
#   60: False,
#   61: False,
#   62: False,
#   64: False,
#   65: False,
#   66: False,
#   68: False,
#   69: False,
#   70: False,
#   72: False,
#   73: False,
#   75: False,
#   77: False,
#   78: False,
#   80: False,
#   81: False,
#   82: False,
#   83: False,
#   84: False,
#   86: False,
#   87: False,
#   89: False,
#   90: False,
#   91: False,
#   92: False,
#   93: False,
#   95: False,
#   97: False,
#   98: False,
#   99: False,
#   100: False,
#   101: False,
#   105: False,
#   106: False,
#   109: False,
#   110: False,
#   112: False,
#   113: False,
#   116: False,
#   118: False,
#   119: False,
#   120: False,
#   121: False,
#   122: False,
#   123: False,
#   124: False,
#   126: False,
#   128: False,
#   129: False,
#   131: False,
#   133: False,
#   134: False,
#   135: False,
#   137: False,
#   138: False,
#   139: False,
#   140: False,
#   141: False,
#   142: False,
#   143: False,
#   144: False,
#   145: False,
#   146: False,
#   148: False,
#   151: False,
#   153: False,
#   154: False,
#   156: False,
#   157: False,
#   158: False,
#   159: False,
#   160: False,
#   163: False,
#   164: False,
#   167: False,
#   169: False,
#   170: False,
#   171: False,
#   172: False,
#   173: False,
#   174: False,
#   177: False,
#   178: False,
#   181: False,
#   182: False,
#   186: False,
#   187: False,
#   188: False,
#   190: False,
#   192: False,
#   193: False,
#   194: False,
#   195: False,
#   196: False,
#   197: False,
#   198: False,
#   199: False,
#   202: False,
#   204: False,
#   205: False,
#   206: False,
#   207: False,
#   208: False,
#   209: False,
#   210: False,
#   212: False,
#   213: False,
#   214: False,
#   219: False,
#   220: False,
#   221: False,
#   222: False,
#   223: False,
#   224: False,
#   228: False,
#   229: False,
#   230: False,
#   231: False,
#   232: False,
#   233: False,
#   235: False,
#   237: False,
#   238: False,
#   239: False,
#   241: False,
#   242: False,
#   243: False,
#   244: False,
#   245: False,
#   247: False,
#   248: False,
#   249: False,
#   253: False,
#   254: False,
#   255: False,
#   256: False,
#   257: False,
#   258: False,
#   260: False,
#   262: False,
#   263: False,
#   264: False,
#   265: False,
#   266: False,
#   267: False,
#   268: False,
#   272: False,
#   273: False,
#   275: False,
#   276: False,
#   277: False,
#   279: False,
#   280: False,
#   283: False,
#   285: False,
#   287: False,
#   288: False,
#   289: False,
#   290: False,
#   291: False,
#   292: False,
#   293: False,
#   294: False,
#   295: False,
#   298: False,
#   300: False,
#   301: False,
#   302: False,
#   303: False,
#   304: False,
#   305: False,
#   306: False,
#   307: False,
#   308: False,
#   310: False,
#   311: False,
#   312: False,
#   313: False,
#   316: False,
#   317: False,
#   320: False,
#   321: False,
#   322: False,
#   323: False,
#   324: False,
#   326: False,
#   327: False,
#   328: False,
#   330: False,
#   332: False,
#   333: False,
#   334: False,
#   335: False,
#   336: False,
#   337: False,
#   338: False,
#   339: False,
#   341: False,
#   343: False,
#   347: False,
#   349: False,
#   350: False,
#   351: False,
#   352: False,
#   353: False,
#   355: False,
#   356: False,
#   357: False,
#   358: False,
#   359: False,
#   360: False,
#   361: False,
#   362: False,
#   363: False,
#   364: False,
#   366: False,
#   367: False,
#   369: False,
#   370: False,
#   371: False,
#   372: False,
#   373: False,
#   374: False,
#   375: False,
#   377: False,
#   379: False,
#   380: False,
#   381: False,
#   383: False,
#   384: False,
#   385: False,
#   386: False,
#   387: False,
#   388: False,
#   390: False,
#   391: False,
#   392: False,
#   393: False,
#   394: False,
#   396: False,
#   397: False,
#   399: False,
#   401: False,
#   402: False,
#   403: False,
#   405: False,
#   406: False,
#   407: False,
#   408: False,
#   409: False,
#   411: False,
#   412: False,
#   413: False,
#   415: False,
#   416: False,
#   418: False,
#   419: False,
#   420: False,
#   421: False,
#   422: False,
#   424: False,
#   425: False,
#   426: False,
#   429: False,
#   430: False,
#   431: False,
#   432: False,
#   433: False,
#   434: False,
#   435: False,
#   436: False,
#   437: False,
#   438: False,
#   440: False,
#   441: False,
#   442: False,
#   443: False,
#   444: False,
#   446: False,
#   447: False,
#   448: False,
#   450: False,
#   452: False,
#   453: False,
#   455: False,
#   456: False,
#   457: False,
#   458: False,
#   459: False,
#   460: False,
#   461: False,
#   462: False,
#   463: False,
#   465: False,
#   466: False,
#   468: False,
#   469: False,
#   470: False,
#   471: False,
#   476: False,
#   478: False,
#   480: False,
#   481: False,
#   482: False,
#   485: False,
#   486: False,
#   487: False,
#   488: False,
#   489: False,
#   490: False,
#   491: False,
#   492: False,
#   495: False,
#   496: False,
#   497: False,
#   498: False,
#   499: False,
#   500: False,
#   501: False,
#   502: False,
#   505: False,
#   506: False,
#   507: False,
#   508: False,
#   509: False,
#   510: False,
#   511: False,
#   512: False,
#   514: False,
#   515: False,
#   516: False,
#   517: False,
#   518: False,
#   519: False,
#   524: False,
#   526: False,
#   529: False,
#   530: False,
#   531: False,
#   532: False,
#   533: False,
#   535: False,
#   537: False,
#   538: False,
#   539: False,
#   540: False,
#   541: False,
#   543: False,
#   544: False,
#   545: False,
#   547: False,
#   548: False,
#   549: False,
#   550: False,
#   551: False,
#   553: False,
#   554: False,
#   555: False,
#   556: False,
#   559: False,
#   560: False,
#   561: False,
#   564: False,
#   566: False,
#   569: False,
#   571: False,
#   573: False,
#   574: False,
#   575: False,
#   576: False,
#   577: False,
#   579: False,
#   580: False},
#  7: {0: False,
#   1: True,
#   2: False,
#   6: False,
#   8: True,
#   9: False,
#   10: False,
#   11: False,
#   13: False,
#   14: False,
#   15: False,
#   16: False,
#   17: False,
#   18: False,
#   19: False,
#   21: False,
#   22: False,
#   23: False,
#   25: False,
#   27: False,
#   28: False,
#   31: True,
#   32: False,
#   33: False,
#   35: False,
#   36: False,
#   37: False,
#   38: False,
#   39: False,
#   43: True,
#   46: False,
#   47: False,
#   48: True,
#   49: True,
#   51: False,
#   52: False,
#   53: False,
#   56: False,
#   57: False,
#   58: False,
#   59: False,
#   60: False,
#   61: False,
#   62: False,
#   64: False,
#   65: True,
#   66: False,
#   68: False,
#   69: True,
#   70: False,
#   72: False,
#   73: False,
#   75: False,
#   77: True,
#   78: False,
#   80: False,
#   81: True,
#   82: False,
#   83: False,
#   84: False,
#   86: False,
#   87: False,
#   89: False,
#   90: False,
#   91: False,
#   92: False,
#   93: False,
#   95: True,
#   97: False,
#   98: False,
#   99: False,
#   100: False,
#   101: False,
#   105: False,
#   106: False,
#   109: False,
#   110: False,
#   112: False,
#   113: False,
#   116: False,
#   118: False,
#   119: True,
#   120: False,
#   121: False,
#   122: True,
#   123: False,
#   124: False,
#   126: False,
#   128: True,
#   129: False,
#   131: False,
#   133: False,
#   134: False,
#   135: True,
#   137: False,
#   138: True,
#   139: False,
#   140: False,
#   141: False,
#   142: False,
#   143: False,
#   144: False,
#   145: False,
#   146: False,
#   148: False,
#   151: False,
#   153: False,
#   154: False,
#   156: False,
#   157: False,
#   158: False,
#   159: True,
#   160: False,
#   163: False,
#   164: False,
#   167: True,
#   169: False,
#   170: False,
#   171: False,
#   172: False,
#   173: False,
#   174: False,
#   177: True,
#   178: False,
#   181: True,
#   182: False,
#   186: False,
#   187: False,
#   188: False,
#   190: False,
#   192: False,
#   193: True,
#   194: False,
#   195: False,
#   196: False,
#   197: False,
#   198: False,
#   199: False,
#   202: False,
#   204: False,
#   205: False,
#   206: False,
#   207: False,
#   208: False,
#   209: False,
#   210: False,
#   212: False,
#   213: False,
#   214: False,
#   219: False,
#   220: False,
#   221: False,
#   222: True,
#   223: False,
#   224: True,
#   228: False,
#   229: False,
#   230: False,
#   231: False,
#   232: False,
#   233: False,
#   235: False,
#   237: False,
#   238: False,
#   239: False,
#   241: False,
#   242: False,
#   243: False,
#   244: False,
#   245: False,
#   247: False,
#   248: False,
#   249: True,
#   253: False,
#   254: False,
#   255: False,
#   256: False,
#   257: True,
#   258: False,
#   260: False,
#   262: False,
#   263: False,
#   264: True,
#   265: False,
#   266: False,
#   267: True,
#   268: False,
#   272: True,
#   273: False,
#   275: False,
#   276: False,
#   277: False,
#   279: True,
#   280: False,
#   283: False,
#   285: False,
#   287: False,
#   288: False,
#   289: True,
#   290: False,
#   291: False,
#   292: False,
#   293: False,
#   294: False,
#   295: False,
#   298: False,
#   300: False,
#   301: False,
#   302: False,
#   303: False,
#   304: False,
#   305: False,
#   306: False,
#   307: False,
#   308: False,
#   310: False,
#   311: False,
#   312: False,
#   313: False,
#   316: False,
#   317: False,
#   320: False,
#   321: False,
#   322: True,
#   323: False,
#   324: True,
#   326: True,
#   327: False,
#   328: True,
#   330: False,
#   332: False,
#   333: True,
#   334: True,
#   335: False,
#   336: False,
#   337: False,
#   338: False,
#   339: False,
#   341: False,
#   343: False,
#   347: False,
#   349: False,
#   350: False,
#   351: False,
#   352: False,
#   353: False,
#   355: False,
#   356: False,
#   357: False,
#   358: False,
#   359: False,
#   360: False,
#   361: False,
#   362: False,
#   363: True,
#   364: True,
#   366: False,
#   367: False,
#   369: True,
#   370: False,
#   371: False,
#   372: False,
#   373: False,
#   374: False,
#   375: False,
#   377: False,
#   379: True,
#   380: False,
#   381: True,
#   383: False,
#   384: False,
#   385: False,
#   386: False,
#   387: False,
#   388: False,
#   390: False,
#   391: True,
#   392: True,
#   393: False,
#   394: True,
#   396: False,
#   397: False,
#   399: True,
#   401: False,
#   402: False,
#   403: False,
#   405: False,
#   406: False,
#   407: False,
#   408: False,
#   409: True,
#   411: False,
#   412: False,
#   413: False,
#   415: False,
#   416: True,
#   418: False,
#   419: False,
#   420: True,
#   421: True,
#   422: True,
#   424: False,
#   425: False,
#   426: False,
#   429: False,
#   430: False,
#   431: False,
#   432: True,
#   433: False,
#   434: False,
#   435: False,
#   436: False,
#   437: False,
#   438: True,
#   440: False,
#   441: False,
#   442: False,
#   443: False,
#   444: False,
#   446: False,
#   447: False,
#   448: True,
#   450: False,
#   452: False,
#   453: False,
#   455: True,
#   456: False,
#   457: False,
#   458: True,
#   459: False,
#   460: False,
#   461: False,
#   462: True,
#   463: True,
#   465: False,
#   466: False,
#   468: False,
#   469: False,
#   470: False,
#   471: False,
#   476: True,
#   478: False,
#   480: False,
#   481: False,
#   482: True,
#   485: False,
#   486: False,
#   487: False,
#   488: False,
#   489: False,
#   490: False,
#   491: False,
#   492: False,
#   495: False,
#   496: False,
#   497: False,
#   498: False,
#   499: False,
#   500: False,
#   501: False,
#   502: False,
#   505: True,
#   506: True,
#   507: False,
#   508: False,
#   509: True,
#   510: True,
#   511: False,
#   512: False,
#   514: False,
#   515: False,
#   516: False,
#   517: False,
#   518: False,
#   519: False,
#   524: False,
#   526: False,
#   529: False,
#   530: False,
#   531: False,
#   532: True,
#   533: False,
#   535: False,
#   537: False,
#   538: False,
#   539: True,
#   540: False,
#   541: False,
#   543: True,
#   544: False,
#   545: False,
#   547: False,
#   548: False,
#   549: False,
#   550: False,
#   551: False,
#   553: False,
#   554: False,
#   555: False,
#   556: False,
#   559: False,
#   560: False,
#   561: True,
#   564: False,
#   566: False,
#   569: False,
#   571: False,
#   573: True,
#   574: False,
#   575: False,
#   576: False,
#   577: False,
#   579: False,
#   580: False},
#  8: {0: False,
#   1: True,
#   2: False,
#   6: False,
#   7: True,
#   9: False,
#   10: False,
#   11: False,
#   13: False,
#   14: False,
#   15: False,
#   16: False,
#   17: False,
#   18: False,
#   19: False,
#   21: False,
#   22: False,
#   23: False,
#   25: False,
#   27: False,
#   28: False,
#   31: True,
#   32: False,
#   33: False,
#   35: False,
#   36: False,
#   37: False,
#   38: False,
#   39: False,
#   43: True,
#   46: False,
#   47: False,
#   48: False,
#   49: True,
#   51: False,
#   52: False,
#   53: False,
#   56: False,
#   57: False,
#   58: False,
#   59: False,
#   60: False,
#   61: False,
#   62: False,
#   64: False,
#   65: True,
#   66: False,
#   68: False,
#   69: True,
#   70: False,
#   72: True,
#   73: False,
#   75: False,
#   77: True,
#   78: False,
#   80: False,
#   81: True,
#   82: False,
#   83: False,
#   84: False,
#   86: False,
#   87: False,
#   89: False,
#   90: False,
#   91: False,
#   92: False,
#   93: False,
#   95: True,
#   97: False,
#   98: False,
#   99: False,
#   100: False,
#   101: False,
#   105: False,
#   106: False,
#   109: False,
#   110: False,
#   112: False,
#   113: False,
#   116: False,
#   118: False,
#   119: True,
#   120: False,
#   121: False,
#   122: True,
#   123: False,
#   124: False,
#   126: False,
#   128: True,
#   129: False,
#   131: False,
#   133: False,
#   134: False,
#   135: True,
#   137: False,
#   138: True,
#   139: False,
#   140: False,
#   141: False,
#   142: False,
#   143: False,
#   144: False,
#   145: False,
#   146: False,
#   148: False,
#   151: False,
#   153: False,
#   154: False,
#   156: False,
#   157: False,
#   158: False,
#   159: True,
#   160: False,
#   163: False,
#   164: False,
#   167: False,
#   169: False,
#   170: False,
#   171: True,
#   172: False,
#   173: False,
#   174: False,
#   177: True,
#   178: False,
#   181: False,
#   182: False,
#   186: False,
#   187: False,
#   188: False,
#   190: False,
#   192: False,
#   193: True,
#   194: False,
#   195: False,
#   196: False,
#   197: False,
#   198: False,
#   199: False,
#   202: False,
#   204: False,
#   205: False,
#   206: False,
#   207: False,
#   208: False,
#   209: False,
#   210: False,
#   212: False,
#   213: False,
#   214: False,
#   219: False,
#   220: False,
#   221: False,
#   222: True,
#   223: False,
#   224: True,
#   228: False,
#   229: False,
#   230: False,
#   231: False,
#   232: False,
#   233: False,
#   235: False,
#   237: False,
#   238: False,
#   239: False,
#   241: False,
#   242: False,
#   243: False,
#   244: False,
#   245: False,
#   247: False,
#   248: False,
#   249: True,
#   253: False,
#   254: False,
#   255: False,
#   256: False,
#   257: True,
#   258: False,
#   260: False,
#   262: False,
#   263: False,
#   264: True,
#   265: False,
#   266: False,
#   267: True,
#   268: False,
#   272: True,
#   273: False,
#   275: False,
#   276: False,
#   277: False,
#   279: True,
#   280: False,
#   283: False,
#   285: False,
#   287: False,
#   288: False,
#   289: False,
#   290: False,
#   291: False,
#   292: False,
#   293: False,
#   294: False,
#   295: False,
#   298: True,
#   300: True,
#   301: False,
#   302: True,
#   303: False,
#   304: False,
#   305: False,
#   306: False,
#   307: False,
#   308: False,
#   310: True,
#   311: False,
#   312: False,
#   313: False,
#   316: False,
#   317: False,
#   320: False,
#   321: False,
#   322: True,
#   323: False,
#   324: True,
#   326: True,
#   327: False,
#   328: True,
#   330: False,
#   332: False,
#   333: False,
#   334: False,
#   335: False,
#   336: False,
#   337: False,
#   338: False,
#   339: False,
#   341: False,
#   343: False,
#   347: False,
#   349: False,
#   350: False,
#   351: False,
#   352: True,
#   353: False,
#   355: False,
#   356: False,
#   357: False,
#   358: False,
#   359: False,
#   360: False,
#   361: False,
#   362: False,
#   363: True,
#   364: True,
#   366: False,
#   367: False,
#   369: True,
#   370: False,
#   371: False,
#   372: False,
#   373: False,
#   374: False,
#   375: False,
#   377: False,
#   379: True,
#   380: False,
#   381: True,
#   383: False,
#   384: True,
#   385: False,
#   386: False,
#   387: False,
#   388: False,
#   390: False,
#   391: True,
#   392: True,
#   393: False,
#   394: False,
#   396: False,
#   397: False,
#   399: True,
#   401: False,
#   402: False,
#   403: False,
#   405: False,
#   406: False,
#   407: False,
#   408: False,
#   409: True,
#   411: False,
#   412: False,
#   413: False,
#   415: False,
#   416: True,
#   418: False,
#   419: False,
#   420: True,
#   421: False,
#   422: True,
#   424: True,
#   425: False,
#   426: True,
#   429: False,
#   430: True,
#   431: False,
#   432: True,
#   433: False,
#   434: False,
#   435: False,
#   436: False,
#   437: False,
#   438: True,
#   440: False,
#   441: False,
#   442: False,
#   443: False,
#   444: False,
#   446: False,
#   447: False,
#   448: True,
#   450: False,
#   452: False,
#   453: False,
#   455: True,
#   456: False,
#   457: False,
#   458: False,
#   459: False,
#   460: False,
#   461: True,
#   462: False,
#   463: False,
#   465: False,
#   466: False,
#   468: False,
#   469: False,
#   470: False,
#   471: False,
#   476: True,
#   478: False,
#   480: False,
#   481: False,
#   482: False,
#   485: False,
#   486: False,
#   487: False,
#   488: False,
#   489: False,
#   490: False,
#   491: False,
#   492: False,
#   495: False,
#   496: False,
#   497: False,
#   498: False,
#   499: False,
#   500: False,
#   501: False,
#   502: False,
#   505: True,
#   506: False,
#   507: False,
#   508: False,
#   509: False,
#   510: True,
#   511: False,
#   512: False,
#   514: False,
#   515: False,
#   516: False,
#   517: False,
#   518: False,
#   519: False,
#   524: False,
#   526: False,
#   529: True,
#   530: False,
#   531: False,
#   532: True,
#   533: False,
#   535: False,
#   537: False,
#   538: False,
#   539: False,
#   540: False,
#   541: False,
#   543: True,
#   544: False,
#   545: True,
#   547: False,
#   548: False,
#   549: False,
#   550: False,
#   551: False,
#   553: False,
#   554: False,
#   555: False,
#   556: False,
#   559: False,
#   560: False,
#   561: True,
#   564: False,
#   566: False,
#   569: False,
#   571: False,
#   573: True,
#   574: False,
#   575: False,
#   576: False,
#   577: False,
#   579: False,
#   580: False},
#  9: {0: False,
#   1: False,
#   2: False,
#   6: False,
#   7: False,
#   8: False,
#   10: False,
#   11: False,
#   13: False,
#   14: False,
#   15: False,
#   16: False,
#   17: False,
#   18: False,
#   19: False,
#   21: False,
#   22: False,
#   23: False,
#   25: False,
#   27: False,
#   28: False,
#   31: False,
#   32: False,
#   33: False,
#   35: False,
#   36: False,
#   37: False,
#   38: False,
#   39: False,
#   43: False,
#   46: False,
#   47: False,
#   48: False,
#   49: False,
#   51: False,
#   52: False,
#   53: False,
#   56: False,
#   57: False,
#   58: False,
#   59: False,
#   60: False,
#   61: False,
#   62: False,
#   64: False,
#   65: False,
#   66: False,
#   68: False,
#   69: False,
#   70: False,
#   72: False,
#   73: False,
#   75: False,
#   77: False,
#   78: False,
#   80: False,
#   81: False,
#   82: False,
#   83: False,
#   84: False,
#   86: False,
#   87: False,
#   89: False,
#   90: False,
#   91: False,
#   92: False,
#   93: False,
#   95: False,
#   97: False,
#   98: False,
#   99: False,
#   100: False,
#   101: False,
#   105: False,
#   106: False,
#   109: False,
#   110: False,
#   112: False,
#   113: False,
#   116: False,
#   118: False,
#   119: False,
#   120: False,
#   121: False,
#   122: False,
#   123: False,
#   124: False,
#   126: False,
#   128: False,
#   129: False,
#   131: False,
#   133: False,
#   134: False,
#   135: False,
#   137: False,
#   138: False,
#   139: False,
#   140: False,
#   141: False,
#   142: False,
#   143: False,
#   144: False,
#   145: False,
#   146: False,
#   148: False,
#   151: False,
#   153: False,
#   154: False,
#   156: False,
#   157: False,
#   158: False,
#   159: False,
#   160: False,
#   163: False,
#   164: False,
#   167: False,
#   169: False,
#   170: False,
#   171: False,
#   172: False,
#   173: False,
#   174: False,
#   177: False,
#   178: False,
#   181: False,
#   182: False,
#   186: False,
#   187: False,
#   188: False,
#   190: False,
#   192: False,
#   193: False,
#   194: False,
#   195: False,
#   196: False,
#   197: False,
#   198: False,
#   199: False,
#   202: False,
#   204: False,
#   205: False,
#   206: False,
#   207: False,
#   208: False,
#   209: False,
#   210: False,
#   212: False,
#   213: False,
#   214: False,
#   219: False,
#   220: False,
#   221: False,
#   222: False,
#   223: False,
#   224: False,
#   228: False,
#   229: False,
#   230: False,
#   231: False,
#   232: False,
#   233: False,
#   235: False,
#   237: False,
#   238: False,
#   239: False,
#   241: False,
#   242: False,
#   243: False,
#   244: False,
#   245: False,
#   247: False,
#   248: False,
#   249: False,
#   253: False,
#   254: False,
#   255: False,
#   256: False,
#   257: False,
#   258: False,
#   260: False,
#   262: False,
#   263: False,
#   264: False,
#   265: False,
#   266: False,
#   267: False,
#   268: False,
#   272: False,
#   273: False,
#   275: False,
#   276: False,
#   277: False,
#   279: False,
#   280: False,
#   283: False,
#   285: False,
#   287: False,
#   288: False,
#   289: False,
#   290: False,
#   291: False,
#   292: False,
#   293: False,
#   294: False,
#   295: False,
#   298: False,
#   300: False,
#   301: False,
#   302: False,
#   303: False,
#   304: False,
#   305: False,
#   306: False,
#   307: False,
#   308: False,
#   310: False,
#   311: False,
#   312: False,
#   313: False,
#   316: False,
#   317: False,
#   320: False,
#   321: False,
#   322: False,
#   323: False,
#   324: False,
#   326: False,
#   327: False,
#   328: False,
#   330: False,
#   332: False,
#   333: False,
#   334: False,
#   335: False,
#   336: False,
#   337: False,
#   338: False,
#   339: False,
#   341: False,
#   343: False,
#   347: False,
#   349: False,
#   350: False,
#   351: False,
#   352: False,
#   353: False,
#   355: False,
#   356: False,
#   357: False,
#   358: False,
#   359: False,
#   360: False,
#   361: False,
#   362: False,
#   363: False,
#   364: False,
#   366: False,
#   367: False,
#   369: False,
#   370: False,
#   371: False,
#   372: False,
#   373: False,
#   374: False,
#   375: False,
#   377: False,
#   379: False,
#   380: False,
#   381: False,
#   383: False,
#   384: False,
#   385: False,
#   386: False,
#   387: False,
#   388: False,
#   390: False,
#   391: False,
#   392: False,
#   393: False,
#   394: False,
#   396: False,
#   397: False,
#   399: False,
#   401: False,
#   402: False,
#   403: False,
#   405: False,
#   406: False,
#   407: False,
#   408: False,
#   409: False,
#   411: False,
#   412: False,
#   413: False,
#   415: False,
#   416: False,
#   418: False,
#   419: False,
#   420: False,
#   421: False,
#   422: False,
#   424: False,
#   425: False,
#   426: False,
#   429: False,
#   430: False,
#   431: False,
#   432: False,
#   433: False,
#   434: False,
#   435: False,
#   436: False,
#   437: False,
#   438: False,
#   440: False,
#   441: False,
#   442: False,
#   443: False,
#   444: False,
#   446: False,
#   447: False,
#   448: False,
#   450: False,
#   452: False,
#   453: False,
#   455: False,
#   456: False,
#   457: False,
#   458: False,
#   459: False,
#   460: False,
#   461: False,
#   462: False,
#   463: False,
#   465: False,
#   466: False,
#   468: False,
#   469: False,
#   470: False,
#   471: False,
#   476: False,
#   478: False,
#   480: False,
#   481: False,
#   482: False,
#   485: False,
#   486: False,
#   487: False,
#   488: False,
#   489: False,
#   490: False,
#   491: False,
#   492: False,
#   495: False,
#   496: False,
#   497: False,
#   498: False,
#   499: False,
#   500: False,
#   501: False,
#   502: False,
#   505: False,
#   506: False,
#   507: False,
#   508: False,
#   509: False,
#   510: False,
#   511: False,
#   512: False,
#   514: False,
#   515: False,
#   516: False,
#   517: False,
#   518: False,
#   519: False,
#   524: False,
#   526: False,
#   529: False,
#   530: False,
#   531: False,
#   532: False,
#   533: False,
#   535: False,
#   537: False,
#   538: False,
#   539: False,
#   540: False,
#   541: False,
#   543: False,
#   544: False,
#   545: False,
#   547: False,
#   548: False,
#   549: False,
#   550: False,
#   551: False,
#   553: False,
#   554: False,
#   555: False,
#   556: False,
#   559: False,
#   560: False,
#   561: False,
#   564: False,
#   566: False,
#   569: False,
#   571: False,
#   573: False,
#   574: False,
#   575: False,
#   576: False,
#   577: False,
#   579: False,
#   580: False},
#  10: {0: True,
#   1: False,
#   2: False,
#   6: False,
#   7: False,
#   8: False,
#   9: False,
#   11: False,
#   13: False,
#   14: True,
#   15: False,
#   16: False,
#   17: True,
#   18: False,
#   19: False,
#   21: False,
#   22: False,
#   23: False,
#   25: False,
#   27: False,
#   28: False,
#   31: False,
#   32: False,
#   33: False,
#   35: False,
#   36: False,
#   37: False,
#   38: False,
#   39: False,
#   43: False,
#   46: False,
#   47: False,
#   48: False,
#   49: False,
#   51: False,
#   52: False,
#   53: False,
#   56: False,
#   57: False,
#   58: False,
#   59: True,
#   60: False,
#   61: False,
#   62: False,
#   64: False,
#   65: False,
#   66: False,
#   68: False,
#   69: False,
#   70: False,
#   72: False,
#   73: False,
#   75: False,
#   77: False,
#   78: False,
#   80: False,
#   81: False,
#   82: False,
#   83: False,
#   84: False,
#   86: False,
#   87: False,
#   89: True,
#   90: False,
#   91: False,
#   92: False,
#   93: False,
#   95: False,
#   97: False,
#   98: False,
#   99: False,
#   100: False,
#   101: False,
#   105: False,
#   106: False,
#   109: False,
#   110: False,
#   112: False,
#   113: False,
#   116: False,
#   118: False,
#   119: False,
#   120: False,
#   121: False,
#   122: False,
#   123: False,
#   124: False,
#   126: False,
#   128: False,
#   129: False,
#   131: True,
#   133: False,
#   134: False,
#   135: False,
#   137: False,
#   138: False,
#   139: False,
#   140: False,
#   141: False,
#   142: False,
#   143: False,
#   144: False,
#   145: True,
#   146: False,
#   148: False,
#   151: False,
#   153: False,
#   154: False,
#   156: False,
#   157: False,
#   158: False,
#   159: False,
#   160: False,
#   163: False,
#   164: False,
#   167: False,
#   169: False,
#   170: False,
#   171: False,
#   172: False,
#   173: False,
#   174: False,
#   177: False,
#   178: False,
#   181: False,
#   182: False,
#   186: False,
#   187: False,
#   188: False,
#   190: False,
#   192: False,
#   193: False,
#   194: False,
#   195: False,
#   196: False,
#   197: False,
#   198: False,
#   199: False,
#   202: False,
#   204: False,
#   205: True,
#   206: False,
#   207: False,
#   208: False,
#   209: False,
#   210: False,
#   212: False,
#   213: False,
#   214: False,
#   219: False,
#   220: False,
#   221: False,
#   222: False,
#   223: False,
#   224: False,
#   228: False,
#   229: False,
#   230: False,
#   231: False,
#   232: False,
#   233: False,
#   235: False,
#   237: False,
#   238: False,
#   239: False,
#   241: False,
#   242: False,
#   243: False,
#   244: False,
#   245: False,
#   247: False,
#   248: True,
#   249: False,
#   253: True,
#   254: False,
#   255: False,
#   256: False,
#   257: False,
#   258: False,
#   260: False,
#   262: False,
#   263: False,
#   264: False,
#   265: False,
#   266: False,
#   267: False,
#   268: False,
#   272: False,
#   273: False,
#   275: False,
#   276: False,
#   277: False,
#   279: False,
#   280: False,
#   283: False,
#   285: False,
#   287: False,
#   288: True,
#   289: False,
#   290: False,
#   291: False,
#   292: False,
#   293: False,
#   294: True,
#   295: False,
#   298: False,
#   300: False,
#   301: True,
#   302: False,
#   303: False,
#   304: False,
#   305: False,
#   306: False,
#   307: False,
#   308: False,
#   310: False,
#   311: False,
#   312: False,
#   313: False,
#   316: False,
#   317: False,
#   320: False,
#   321: False,
#   322: False,
#   323: False,
#   324: False,
#   326: False,
#   327: False,
#   328: False,
#   330: False,
#   332: False,
#   333: False,
#   334: False,
#   335: True,
#   336: False,
#   337: False,
#   338: False,
#   339: False,
#   341: False,
#   343: False,
#   347: False,
#   349: False,
#   350: False,
#   351: False,
#   352: False,
#   353: False,
#   355: False,
#   356: False,
#   357: False,
#   358: False,
#   359: False,
#   360: False,
#   361: True,
#   362: False,
#   363: False,
#   364: False,
#   366: True,
#   367: False,
#   369: False,
#   370: False,
#   371: True,
#   372: False,
#   373: False,
#   374: False,
#   375: True,
#   377: False,
#   379: False,
#   380: False,
#   381: False,
#   383: False,
#   384: False,
#   385: False,
#   386: False,
#   387: False,
#   388: False,
#   390: False,
#   391: False,
#   392: False,
#   393: False,
#   394: False,
#   396: False,
#   397: False,
#   399: False,
#   401: False,
#   402: False,
#   403: False,
#   405: False,
#   406: False,
#   407: False,
#   408: False,
#   409: False,
#   411: False,
#   412: True,
#   413: False,
#   415: False,
#   416: False,
#   418: False,
#   419: False,
#   420: False,
#   421: False,
#   422: False,
#   424: False,
#   425: False,
#   426: False,
#   429: False,
#   430: False,
#   431: False,
#   432: False,
#   433: False,
#   434: False,
#   435: False,
#   436: False,
#   437: True,
#   438: False,
#   440: False,
#   441: False,
#   442: False,
#   443: False,
#   444: False,
#   446: False,
#   447: False,
#   448: False,
#   450: True,
#   452: False,
#   453: False,
#   455: False,
#   456: False,
#   457: False,
#   458: False,
#   459: False,
#   460: False,
#   461: False,
#   462: False,
#   463: False,
#   465: False,
#   466: False,
#   468: False,
#   469: False,
#   470: False,
#   471: True,
#   476: False,
#   478: False,
#   480: False,
#   481: False,
#   482: False,
#   485: True,
#   486: False,
#   487: False,
#   488: False,
#   489: False,
#   490: False,
#   491: False,
#   492: False,
#   495: False,
#   496: False,
#   497: False,
#   498: False,
#   499: True,
#   500: False,
#   501: False,
#   502: False,
#   505: False,
#   506: False,
#   507: False,
#   508: False,
#   509: False,
#   510: False,
#   511: False,
#   512: False,
#   514: False,
#   515: False,
#   516: False,
#   517: False,
#   518: True,
#   519: False,
#   524: False,
#   526: False,
#   529: False,
#   530: False,
#   531: False,
#   532: False,
#   533: False,
#   535: False,
#   537: False,
#   538: False,
#   539: False,
#   540: True,
#   541: False,
#   543: False,
#   544: False,
#   545: False,
#   547: False,
#   548: False,
#   549: False,
#   550: False,
#   551: False,
#   553: False,
#   554: False,
#   555: False,
#   556: False,
#   559: False,
#   560: False,
#   561: False,
#   564: False,
#   566: False,
#   569: False,
#   571: False,
#   573: False,
#   574: False,
#   575: False,
#   576: False,
#   577: False,
#   579: True,
#   580: False},
#  11: {0: False,
#   1: False,
#   2: False,
#   6: False,
#   7: False,
#   8: False,
#   9: False,
#   10: False,
#   13: False,
#   14: False,
#   15: False,
#   16: False,
#   17: False,
#   18: False,
#   19: False,
#   21: False,
#   22: False,
#   23: False,
#   25: False,
#   27: False,
#   28: False,
#   31: False,
#   32: False,
#   33: False,
#   35: False,
#   36: False,
#   37: False,
#   38: False,
#   39: True,
#   43: False,
#   46: False,
#   47: False,
#   48: False,
#   49: False,
#   51: False,
#   52: False,
#   53: False,
#   56: False,
#   57: False,
#   58: False,
#   59: False,
#   60: False,
#   61: True,
#   62: False,
#   64: False,
#   65: False,
#   66: False,
#   68: False,
#   69: True,
#   70: True,
#   72: True,
#   73: False,
#   75: False,
#   77: False,
#   78: False,
#   80: False,
#   81: False,
#   82: False,
#   83: False,
#   84: False,
#   86: False,
#   87: False,
#   89: False,
#   90: False,
#   91: False,
#   92: False,
#   93: True,
#   95: False,
#   97: False,
#   98: False,
#   99: False,
#   100: False,
#   101: False,
#   105: False,
#   106: False,
#   109: False,
#   110: False,
#   112: False,
#   113: True,
#   116: False,
#   118: False,
#   119: False,
#   120: False,
#   121: False,
#   122: True,
#   123: False,
#   124: False,
#   126: False,
#   128: False,
#   129: True,
#   131: False,
#   133: False,
#   134: False,
#   135: False,
#   137: False,
#   138: True,
#   139: False,
#   140: False,
#   141: True,
#   142: False,
#   143: True,
#   144: False,
#   145: False,
#   146: False,
#   148: False,
#   151: False,
#   153: False,
#   154: False,
#   156: False,
#   157: False,
#   158: True,
#   159: True,
#   160: False,
#   163: False,
#   164: True,
#   167: False,
#   169: False,
#   170: False,
#   171: True,
#   172: False,
#   173: False,
#   174: False,
#   177: False,
#   178: False,
#   181: True,
#   182: False,
#   186: False,
#   187: False,
#   188: False,
#   190: False,
#   192: False,
#   193: True,
#   194: False,
#   195: False,
#   196: False,
#   197: False,
#   198: True,
#   199: False,
#   202: False,
#   204: False,
#   205: False,
#   206: False,
#   207: False,
#   208: False,
#   209: False,
#   210: False,
#   212: False,
#   213: False,
#   214: False,
#   219: False,
#   220: False,
#   221: False,
#   222: False,
#   223: False,
#   224: False,
#   228: False,
#   229: False,
#   230: False,
#   231: False,
#   232: False,
#   233: False,
#   235: False,
#   237: True,
#   238: True,
#   239: False,
#   241: False,
#   242: False,
#   243: True,
#   244: False,
#   245: False,
#   247: False,
#   248: False,
#   249: False,
#   253: False,
#   254: False,
#   255: False,
#   256: False,
#   257: False,
#   258: False,
#   260: False,
#   262: False,
#   263: False,
#   264: True,
#   265: False,
# ...
#   119: False,
#   120: False,
#   121: False,
#   122: False,
#   123: False,
#   124: False,
#   126: False,
#   128: False,
#   129: False,
#   131: True,
#   133: False,
#   134: False,
#   135: False,
#   137: False,
#   138: False,
#   139: True,
#   140: False,
#   141: False,
#   142: False,
#   143: False,
#   144: False,
#   145: True,
#   146: False,
#   148: False,
#   151: False,
#   153: False,
#   154: False,
#   156: False,
#   157: False,
#   158: False,
#   159: False,
#   160: False,
#   163: False,
#   164: False,
#   167: False,
#   169: False,
#   170: False,
#   171: False,
#   172: False,
#   173: False,
#   174: False,
#   177: False,
#   178: False,
#   181: False,
#   182: False,
#   186: True,
#   187: True,
#   188: False,
#   190: False,
#   192: False,
#   193: False,
#   194: False,
#   195: False,
#   196: False,
#   197: False,
#   198: False,
#   199: False,
#   202: False,
#   204: False,
#   205: True,
#   206: False,
#   207: False,
#   208: False,
#   209: False,
#   210: False,
#   212: False,
#   213: False,
#   214: False,
#   219: False,
#   220: False,
#   221: False,
#   222: False,
#   223: False,
#   224: False,
#   228: False,
#   229: False,
#   230: False,
#   231: False,
#   232: False,
#   233: False,
#   235: False,
#   237: False,
#   238: False,
#   239: False,
#   241: False,
#   242: False,
#   243: False,
#   244: False,
#   245: True,
#   247: True,
#   248: False,
#   249: False,
#   253: False,
#   254: False,
#   255: False,
#   256: True,
#   257: False,
#   258: False,
#   260: False,
#   262: False,
#   263: False,
#   264: False,
#   265: False,
#   266: False,
#   267: False,
#   268: False,
#   272: False,
#   273: False,
#   275: False,
#   276: False,
#   277: False,
#   279: False,
#   280: False,
#   283: False,
#   285: False,
#   287: False,
#   288: True,
#   289: False,
#   290: False,
#   291: False,
#   292: False,
#   293: False,
#   294: False,
#   295: False,
#   298: False,
#   300: False,
#   301: False,
#   302: False,
#   303: False,
#   304: False,
#   305: False,
#   306: False,
#   307: False,
#   308: False,
#   310: False,
#   311: False,
#   312: False,
#   313: False,
#   316: False,
#   317: False,
#   320: False,
#   321: False,
#   322: False,
#   323: False,
#   324: False,
#   326: False,
#   327: False,
#   328: False,
#   330: False,
#   332: False,
#   333: False,
#   334: False,
#   335: True,
#   336: False,
#   337: False,
#   338: False,
#   339: False,
#   341: False,
#   343: False,
#   347: False,
#   349: False,
#   350: False,
#   351: False,
#   352: False,
#   353: False,
#   355: False,
#   356: False,
#   357: False,
#   358: False,
#   359: False,
#   360: False,
#   361: False,
#   362: False,
#   363: False,
#   364: False,
#   366: True,
#   367: False,
#   369: False,
#   370: False,
#   371: True,
#   372: False,
#   373: False,
#   374: False,
#   375: False,
#   377: False,
#   379: False,
#   380: False,
#   381: False,
#   383: False,
#   384: False,
#   385: False,
#   386: False,
#   387: True,
#   388: False,
#   390: True,
#   391: False,
#   392: False,
#   393: False,
#   394: False,
#   396: False,
#   397: False,
#   399: False,
#   401: False,
#   402: False,
#   403: False,
#   405: False,
#   406: False,
#   407: False,
#   408: False,
#   409: False,
#   411: True,
#   412: False,
#   413: False,
#   415: False,
#   416: False,
#   418: False,
#   419: False,
#   420: False,
#   421: False,
#   422: False,
#   424: False,
#   425: False,
#   426: False,
#   429: False,
#   430: False,
#   431: False,
#   432: False,
#   433: False,
#   434: False,
#   435: False,
#   436: True,
#   437: True,
#   438: False,
#   440: False,
#   441: False,
#   442: False,
#   443: False,
#   444: False,
#   446: False,
#   447: False,
#   448: False,
#   450: True,
#   452: False,
#   453: False,
#   455: False,
#   456: False,
#   457: False,
#   458: False,
#   459: False,
#   460: False,
#   461: False,
#   462: False,
#   463: False,
#   465: False,
#   466: True,
#   468: False,
#   469: False,
#   470: False,
#   471: False,
#   476: False,
#   478: False,
#   480: False,
#   481: False,
#   482: False,
#   485: False,
#   486: False,
#   487: False,
#   488: False,
#   489: False,
#   490: False,
#   491: False,
#   492: False,
#   495: False,
#   496: False,
#   497: False,
#   498: False,
#   499: True,
#   500: True,
#   501: False,
#   502: False,
#   505: False,
#   506: False,
#   507: False,
#   508: False,
#   509: False,
#   510: False,
#   511: False,
#   512: True,
#   514: False,
#   515: False,
#   516: False,
#   517: False,
#   518: False,
#   519: False,
#   524: False,
#   526: False,
#   529: False,
#   530: False,
#   531: False,
#   532: False,
#   533: False,
#   535: False,
#   537: False,
#   538: False,
#   539: False,
#   540: False,
#   541: False,
#   543: False,
#   544: False,
#   545: False,
#   547: False,
#   548: False,
#   549: False,
#   550: False,
#   551: False,
#   553: False,
#   554: False,
#   555: False,
#   556: False,
#   559: False,
#   560: False,
#   561: False,
#   564: False,
#   566: False,
#   569: False,
#   571: False,
#   573: False,
#   574: False,
#   575: False,
#   576: False,
#   579: False,
#   580: False},
#  579: {0: True,
#   1: False,
#   2: False,
#   6: False,
#   7: False,
#   8: False,
#   9: False,
#   10: True,
#   11: False,
#   13: False,
#   14: True,
#   15: False,
#   16: False,
#   17: True,
#   18: False,
#   19: False,
#   21: False,
#   22: False,
#   23: False,
#   25: False,
#   27: False,
#   28: False,
#   31: False,
#   32: False,
#   33: False,
#   35: False,
#   36: False,
#   37: False,
#   38: False,
#   39: False,
#   43: False,
#   46: True,
#   47: False,
#   48: False,
#   49: False,
#   51: False,
#   52: False,
#   53: False,
#   56: False,
#   57: False,
#   58: False,
#   59: True,
#   60: False,
#   61: False,
#   62: False,
#   64: False,
#   65: False,
#   66: False,
#   68: False,
#   69: False,
#   70: False,
#   72: False,
#   73: False,
#   75: False,
#   77: False,
#   78: False,
#   80: False,
#   81: False,
#   82: True,
#   83: False,
#   84: False,
#   86: True,
#   87: False,
#   89: True,
#   90: False,
#   91: False,
#   92: False,
#   93: False,
#   95: False,
#   97: False,
#   98: False,
#   99: False,
#   100: False,
#   101: False,
#   105: False,
#   106: False,
#   109: False,
#   110: False,
#   112: True,
#   113: False,
#   116: False,
#   118: False,
#   119: False,
#   120: False,
#   121: False,
#   122: False,
#   123: False,
#   124: False,
#   126: False,
#   128: False,
#   129: False,
#   131: True,
#   133: False,
#   134: False,
#   135: False,
#   137: False,
#   138: False,
#   139: True,
#   140: False,
#   141: False,
#   142: False,
#   143: False,
#   144: False,
#   145: True,
#   146: False,
#   148: False,
#   151: False,
#   153: False,
#   154: False,
#   156: False,
#   157: False,
#   158: False,
#   159: False,
#   160: False,
#   163: False,
#   164: False,
#   167: False,
#   169: False,
#   170: False,
#   171: False,
#   172: False,
#   173: False,
#   174: False,
#   177: False,
#   178: False,
#   181: False,
#   182: False,
#   186: True,
#   187: False,
#   188: False,
#   190: False,
#   192: False,
#   193: False,
#   194: False,
#   195: False,
#   196: False,
#   197: False,
#   198: False,
#   199: False,
#   202: False,
#   204: False,
#   205: True,
#   206: False,
#   207: False,
#   208: False,
#   209: False,
#   210: False,
#   212: False,
#   213: False,
#   214: False,
#   219: False,
#   220: False,
#   221: False,
#   222: False,
#   223: False,
#   224: False,
#   228: False,
#   229: False,
#   230: False,
#   231: False,
#   232: False,
#   233: False,
#   235: False,
#   237: False,
#   238: False,
#   239: False,
#   241: False,
#   242: False,
#   243: False,
#   244: False,
#   245: False,
#   247: True,
#   248: True,
#   249: False,
#   253: True,
#   254: False,
#   255: False,
#   256: True,
#   257: False,
#   258: False,
#   260: False,
#   262: False,
#   263: False,
#   264: False,
#   265: False,
#   266: False,
#   267: False,
#   268: False,
#   272: False,
#   273: False,
#   275: False,
#   276: False,
#   277: False,
#   279: False,
#   280: False,
#   283: False,
#   285: False,
#   287: False,
#   288: True,
#   289: False,
#   290: False,
#   291: False,
#   292: False,
#   293: False,
#   294: True,
#   295: False,
#   298: False,
#   300: False,
#   301: True,
#   302: False,
#   303: False,
#   304: False,
#   305: False,
#   306: False,
#   307: False,
#   308: False,
#   310: False,
#   311: False,
#   312: False,
#   313: False,
#   316: False,
#   317: False,
#   320: False,
#   321: False,
#   322: False,
#   323: False,
#   324: False,
#   326: False,
#   327: False,
#   328: False,
#   330: False,
#   332: False,
#   333: False,
#   334: False,
#   335: True,
#   336: False,
#   337: False,
#   338: False,
#   339: False,
#   341: False,
#   343: True,
#   347: False,
#   349: False,
#   350: False,
#   351: False,
#   352: False,
#   353: False,
#   355: False,
#   356: False,
#   357: False,
#   358: False,
#   359: False,
#   360: False,
#   361: True,
#   362: False,
#   363: False,
#   364: False,
#   366: True,
#   367: False,
#   369: False,
#   370: False,
#   371: True,
#   372: False,
#   373: False,
#   374: False,
#   375: True,
#   377: False,
#   379: False,
#   380: False,
#   381: False,
#   383: False,
#   384: False,
#   385: False,
#   386: False,
#   387: True,
#   388: False,
#   390: True,
#   391: False,
#   392: False,
#   393: False,
#   394: False,
#   396: False,
#   397: False,
#   399: False,
#   401: False,
#   402: False,
#   403: False,
#   405: False,
#   406: False,
#   407: False,
#   408: False,
#   409: False,
#   411: False,
#   412: True,
#   413: False,
#   415: False,
#   416: False,
#   418: False,
#   419: False,
#   420: False,
#   421: False,
#   422: False,
#   424: False,
#   425: False,
#   426: False,
#   429: False,
#   430: False,
#   431: False,
#   432: False,
#   433: False,
#   434: False,
#   435: False,
#   436: False,
#   437: True,
#   438: False,
#   440: False,
#   441: False,
#   442: False,
#   443: False,
#   444: False,
#   446: False,
#   447: False,
#   448: False,
#   450: True,
#   452: False,
#   453: False,
#   455: False,
#   456: False,
#   457: False,
#   458: False,
#   459: False,
#   460: False,
#   461: False,
#   462: False,
#   463: False,
#   465: False,
#   466: False,
#   468: False,
#   469: False,
#   470: False,
#   471: True,
#   476: False,
#   478: False,
#   480: False,
#   481: False,
#   482: False,
#   485: True,
#   486: False,
#   487: False,
#   488: False,
#   489: False,
#   490: False,
#   491: False,
#   492: False,
#   495: False,
#   496: False,
#   497: False,
#   498: False,
#   499: True,
#   500: True,
#   501: False,
#   502: False,
#   505: False,
#   506: False,
#   507: False,
#   508: False,
#   509: False,
#   510: False,
#   511: False,
#   512: True,
#   514: False,
#   515: False,
#   516: False,
#   517: False,
#   518: True,
#   519: False,
#   524: False,
#   526: False,
#   529: False,
#   530: False,
#   531: False,
#   532: False,
#   533: False,
#   535: False,
#   537: False,
#   538: False,
#   539: False,
#   540: True,
#   541: False,
#   543: False,
#   544: False,
#   545: False,
#   547: False,
#   548: False,
#   549: False,
#   550: False,
#   551: False,
#   553: False,
#   554: False,
#   555: False,
#   556: False,
#   559: False,
#   560: False,
#   561: False,
#   564: False,
#   566: False,
#   569: False,
#   571: False,
#   573: False,
#   574: False,
#   575: False,
#   576: False,
#   577: False,
#   580: False},
#  580: {0: False,
#   1: False,
#   2: False,
#   6: False,
#   7: False,
#   8: False,
#   9: False,
#   10: False,
#   11: False,
#   13: False,
#   14: False,
#   15: False,
#   16: False,
#   17: False,
#   18: False,
#   19: False,
#   21: False,
#   22: True,
#   23: False,
#   25: False,
#   27: False,
#   28: False,
#   31: False,
#   32: False,
#   33: False,
#   35: False,
#   36: False,
#   37: True,
#   38: False,
#   39: False,
#   43: False,
#   46: False,
#   47: False,
#   48: False,
#   49: False,
#   51: False,
#   52: False,
#   53: False,
#   56: False,
#   57: False,
#   58: False,
#   59: False,
#   60: False,
#   61: False,
#   62: False,
#   64: False,
#   65: False,
#   66: False,
#   68: False,
#   69: False,
#   70: False,
#   72: False,
#   73: False,
#   75: False,
#   77: False,
#   78: False,
#   80: False,
#   81: False,
#   82: False,
#   83: False,
#   84: False,
#   86: False,
#   87: False,
#   89: False,
#   90: False,
#   91: False,
#   92: False,
#   93: False,
#   95: False,
#   97: False,
#   98: False,
#   99: False,
#   100: False,
#   101: False,
#   105: False,
#   106: False,
#   109: False,
#   110: True,
#   112: False,
#   113: False,
#   116: False,
#   118: False,
#   119: False,
#   120: False,
#   121: False,
#   122: False,
#   123: False,
#   124: False,
#   126: False,
#   128: False,
#   129: False,
#   131: False,
#   133: False,
#   134: False,
#   135: False,
#   137: False,
#   138: False,
#   139: False,
#   140: False,
#   141: False,
#   142: True,
#   143: False,
#   144: False,
#   145: False,
#   146: False,
#   148: False,
#   151: False,
#   153: False,
#   154: False,
#   156: True,
#   157: False,
#   158: False,
#   159: False,
#   160: True,
#   163: False,
#   164: False,
#   167: False,
#   169: False,
#   170: False,
#   171: False,
#   172: False,
#   173: False,
#   174: True,
#   177: False,
#   178: False,
#   181: False,
#   182: False,
#   186: False,
#   187: False,
#   188: False,
#   190: False,
#   192: False,
#   193: False,
#   194: True,
#   195: False,
#   196: False,
#   197: False,
#   198: False,
#   199: False,
#   202: True,
#   204: True,
#   205: False,
#   206: False,
#   207: False,
#   208: False,
#   209: True,
#   210: False,
#   212: False,
#   213: False,
#   214: False,
#   219: False,
#   220: False,
#   221: False,
#   222: False,
#   223: False,
#   224: False,
#   228: False,
#   229: False,
#   230: False,
#   231: False,
#   232: False,
#   233: False,
#   235: False,
#   237: False,
#   238: False,
#   239: True,
#   241: False,
#   242: False,
#   243: False,
#   244: False,
#   245: False,
#   247: False,
#   248: False,
#   249: False,
#   253: False,
#   254: False,
#   255: False,
#   256: False,
#   257: False,
#   258: True,
#   260: False,
#   262: False,
#   263: False,
#   264: False,
#   265: True,
#   266: True,
#   267: False,
#   268: False,
#   272: False,
#   273: False,
#   275: False,
#   276: False,
#   277: False,
#   279: False,
#   280: False,
#   283: False,
#   285: False,
#   287: False,
#   288: False,
#   289: False,
#   290: False,
#   291: False,
#   292: False,
#   293: True,
#   294: False,
#   295: False,
#   298: False,
#   300: False,
#   301: False,
#   302: False,
#   303: False,
#   304: False,
#   305: True,
#   306: False,
#   307: False,
#   308: False,
#   310: False,
#   311: False,
#   312: False,
#   313: False,
#   316: True,
#   317: False,
#   320: True,
#   321: False,
#   322: False,
#   323: False,
#   324: False,
#   326: False,
#   327: False,
#   328: False,
#   330: False,
#   332: False,
#   333: False,
#   334: False,
#   335: False,
#   336: False,
#   337: False,
#   338: True,
#   339: False,
#   341: False,
#   343: False,
#   347: False,
#   349: False,
#   350: False,
#   351: False,
#   352: False,
#   353: False,
#   355: False,
#   356: False,
#   357: False,
#   358: False,
#   359: False,
#   360: True,
#   361: False,
#   362: True,
#   363: False,
#   364: False,
#   366: False,
#   367: False,
#   369: False,
#   370: False,
#   371: False,
#   372: False,
#   373: False,
#   374: True,
#   375: False,
#   377: False,
#   379: False,
#   380: False,
#   381: False,
#   383: False,
#   384: False,
#   385: False,
#   386: False,
#   387: False,
#   388: False,
#   390: False,
#   391: False,
#   392: False,
#   393: False,
#   394: False,
#   396: False,
#   397: False,
#   399: False,
#   401: True,
#   402: False,
#   403: False,
#   405: False,
#   406: False,
#   407: False,
#   408: False,
#   409: False,
#   411: False,
#   412: False,
#   413: False,
#   415: False,
#   416: False,
#   418: True,
#   419: False,
#   420: False,
#   421: False,
#   422: False,
#   424: False,
#   425: False,
#   426: False,
#   429: False,
#   430: False,
#   431: False,
#   432: False,
#   433: False,
#   434: False,
#   435: False,
#   436: False,
#   437: False,
#   438: False,
#   440: False,
#   441: False,
#   442: False,
#   443: False,
#   444: False,
#   446: False,
#   447: False,
#   448: False,
#   450: False,
#   452: False,
#   453: False,
#   455: False,
#   456: False,
#   457: False,
#   458: False,
#   459: False,
#   460: False,
#   461: False,
#   462: False,
#   463: False,
#   465: False,
#   466: False,
#   468: False,
#   469: False,
#   470: False,
#   471: False,
#   476: False,
#   478: False,
#   480: False,
#   481: False,
#   482: False,
#   485: False,
#   486: False,
#   487: True,
#   488: False,
#   489: False,
#   490: False,
#   491: False,
#   492: False,
#   495: False,
#   496: False,
#   497: False,
#   498: False,
#   499: False,
#   500: False,
#   501: False,
#   502: False,
#   505: False,
#   506: False,
#   507: True,
#   508: False,
#   509: False,
#   510: False,
#   511: False,
#   512: False,
#   514: False,
#   515: False,
#   516: False,
#   517: True,
#   518: False,
#   519: False,
#   524: False,
#   526: False,
#   529: False,
#   530: False,
#   531: False,
#   532: False,
#   533: False,
#   535: False,
#   537: True,
#   538: True,
#   539: False,
#   540: False,
#   541: False,
#   543: False,
#   544: False,
#   545: False,
#   547: False,
#   548: False,
#   549: False,
#   550: False,
#   551: False,
#   553: True,
#   554: False,
#   555: False,
#   556: False,
#   559: True,
#   560: False,
#   561: False,
#   564: False,
#   566: False,
#   569: False,
#   571: False,
#   573: False,
#   574: False,
#   575: False,
#   576: False,
#   577: False,
#   579: False}}
